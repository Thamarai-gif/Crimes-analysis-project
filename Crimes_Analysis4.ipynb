# %%
# !pip install openai
# Out:
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------------------- -------------------- 0.8/1.6 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 3.4 MB/s  0:00:00
# ...
#
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
# ...

# %%
# !pip install requests

# %%
import os
import requests

api_key = os.getenv("OPENAI_API_KEY")
url = "https://api.openai.com/v1/chat/completions"

if api_key:
    print(api_key[:5] + "..." + api_key[-5:])  # safe slice
else:
    print("API key not found!")
# Out:
# API key not found!

# %%
import os
import requests

api_key = os.getenv("OPENAI_API_KEY")
url = "https://api.openai.com/v1/chat/completions"

if api_key:
    print(api_key[:5] + "..." + api_key[-5:])  # safe slice
else:
    print("API key not found!")
# Out:
# sk-or...347b8

# %%
import os
import requests

api_key = os.getenv("OPENAI_API_KEY")
url = "https://api.openai.com/v1/chat/completions"

def call_llm(system_prompt, user_prompt, temperature=0.0, max_tokens=512):
    payload = {
        "model": "gpt-4o-mini",
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "temperature": temperature,
        "max_tokens": max_tokens
    }
    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }

    response = requests.post(url, headers=headers, json=payload)

    if response.status_code != 200:
        print("Error:", response.status_code)
        return None

    return response.json()['choices'][0]['message']['content']

# %%
system_prompt = "You are a JSON formatter. Always return valid JSON."
user_prompt = """Reformat this record into target schema:
Target schema: {"name":"string","age":"integer","city":"string"}
Record: {"full_name":"John Doe","years":30,"location":"New York"}"""

output = call_llm(system_prompt, user_prompt)
print("LLM Output:", output)
# Out:
# Error: 401
# LLM Output: None

# %%
import os

api_key = os.getenv("OPENAI_API_KEY")

if api_key:
    print(api_key[:5] + "..." + api_key[-5:])  # show first 5 + last 5
else:
    print("API key not found!")
# Out:
# sk-or...347b8

# %%
import os
import requests

api_key = os.getenv("OPENAI_API_KEY")
url = "https://api.openai.com/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json"
}

payload = {
    "model": "gpt-4o-mini",
    "messages": [
        {"role": "system", "content": "You are a JSON formatter."},
        {"role": "user", "content": "Say hello"}
    ]
}

response = requests.post(url, headers=headers, json=payload)
print("Status:", response.status_code)
print("Body:", response.text)
# Out:
# Status: 401
# Body: {
#   "error": {
#     "message": "Incorrect API key provided: sk-or-v1*************************************************************47b8. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "code": "invalid_api_key",
#     "param": null
#   },
#   "status": 401
# }

# %%
import os
print(os.getenv("OPENAI_API_KEY")[:5] + "..." + os.getenv("OPENAI_API_KEY")[-5:])
# Out:
# sk-or...347b8

# %%
system_prompt = "You are a JSON formatter. Always return valid JSON."
user_prompt = """Reformat this record into target schema:
Target schema: {"name":"string","age":"integer","city":"string"}
Record: {"full_name":"John Doe","years":30,"location":"New York"}"""

output = call_llm(system_prompt, user_prompt)
print("LLM Output:", output)
# Out:
# Error: 401
# LLM Output: None
